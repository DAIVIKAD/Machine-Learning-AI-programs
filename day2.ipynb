# %% [markdown]
# <a href="https://colab.research.google.com/github/DAIVIKAD/Machine-Learning-AI-programs/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x= 20
print(x,type(x))
# Out:
# 20 <class 'int'>

# %%
x= 2,8
print(x,type(x))
# Out:
# 20 <class 'int'>

# %%
x= True
print(x,type(x))
# Out:
# True <class 'bool'>

# %%
x='daivik'
print(x,type(x))
# Out:
# daivik <class 'str'>

# %%
x= 3+5j
print(x,type(x))
# Out:
# (3+5j) <class 'complex'>

# %%
fruits = ["apple","graps","oranage"]
print (fruits[1])
# Out:
# graps

# %%
fruits[1] = 'daivik pineapple'
print (fruits)
# Out:
# ['3', 'daivik pineapple', '1']

# %%
fruits = ["3","2","1"]
print (fruits[0])
# Out:
# 3

# %%
fruits.append ("bannana")
print (fruits)
# Out:
# ['3', 'daivik pineapple', '1', 'bannana']

# %%
student = {"name":"dat","age": 28,'course': 'data science'}
print(student)
# Out:
# {'name': 'dat', 'age': 28, 'course': 'data science'}

# %%
print(student["name"])
# Out:
# dat

# %%
student["university"]="Presidency"
print(student)
# Out:
# {'name': 'dat', 'age': 28, 'course': 'data science', 'university': 'Presidency'}

# %%
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
  print(fruit)
# Out:
# apple
# banana
# cherry
